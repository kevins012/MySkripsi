# %% [markdown]
# # 📘 Judul Utama (Heading 1)
#
# ## 📗 Subjudul (Heading 2)
#
# ### 📘 Subsubjudul (Heading 3)
#
# #### 📎 Heading 4
# ##### Heading 5
# ###### Heading 6 (paling kecil)
#
# ---
#
# ## 🔤 Format Teks
#
# **Teks Tebal** → `**Teks Tebal**`
# *Tulisan Miring* → `*Tulisan Miring*`
# ~~Tulisan Dicoret~~ → `~~Tulisan Dicoret~~`
# `Teks Kode` → `` `Teks Kode` ``
#
# ---
#
# ## 🔗 Link dan Gambar
#
# **Link**:
# [Klik ke Google](https://www.google.com) → `[Klik ke Google](https://www.google.com)`
#
# **Gambar**:
# ![Contoh Gambar](https://via.placeholder.com/150) → `![Contoh Gambar](URL)`
#
# ---
#
# ## 📋 Daftar
#
# **Bullet / Unordered List:**
# - Item 1
# - Item 2
#   - Subitem 2.1
#   - Subitem 2.2
#
# **Numbered / Ordered List:**
# 1. Langkah pertama
# 2. Langkah kedua
#    1. Sub langkah A
#    2. Sub langkah B
#
# **Checklist / Task List:**
# - [x] Selesai
# - [ ] Belum selesai
#
# ---
#
# ## 🧮 Rumus LaTeX (Math)
#
# Inline math:
# `$E = mc^2$` → $E = mc^2$
#
# Block math (centered):

# %% [markdown]
# Hasil:
# $$
# \int_{a}^{b} x^2 \, dx = \frac{b^3 - a^3}{3}
# $$
#
# ---
#
# ## 💻 Code Block
#
# ```python
# # Ini adalah kode Python
# def halo():
#     print("Halo dari Jupyter!")
